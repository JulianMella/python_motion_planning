# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

data_frame = pd.read_csv('file1.csv')

(
    sns.boxplot(
        data_frame,
        x="algorithm",
        y="cost",
        
    )
)

plt.show()
